# %%
import pandas as pd

# File paths
file_paths = {
    "log2cna": "../Datafiles Final/Datafiles Cleaned/log2cna.pkl",
    "methylation": "../Datafiles Final/Datafiles Cleaned/methylation.pkl",
    "mrnaseqv2": "../Datafiles Final/Datafiles Cleaned/mrnaseqv2.pkl"
}

# Function to load and display data
def load_and_display_pkl(file_path, dataset_name):
    df = pd.read_pickle(file_path)
    print(f"\nDisplaying first 5 rows of {dataset_name}:")
    display(df.head())  # Jupyter-friendly display

# %%
file_paths["methylation"]
# Out:
# '../Datafiles Final/Datafiles Cleaned/methylation.pkl'

# %%
load_and_display_pkl(file_paths["methylation"],"methylation")
# Out:
# Displaying first 5 rows of methylation:
#                        0           1           2           3      \
# ENTITY_STABLE_ID  cg00000292  cg00003994  cg00005847  cg00007981
# NAME                  ATP2A1       MEOX2       HOXD3       PANX1
# TCGA-04-1331-01     0.931225     0.04703    0.810362    0.011909
# TCGA-04-1332-01     0.527324    0.055236    0.372304    0.008184
# TCGA-04-1335-01     0.915472    0.084291    0.641705    0.029346
#
#                            4           5           6             7      \
# ENTITY_STABLE_ID      cg00008493  cg00008713  cg00009407    cg00011459
# NAME              KIAA1409;COX8C       IMPA2        TTC8  PMM2;TMEM186
# TCGA-04-1331-01         0.942704    0.054855    0.048007      0.865935
# TCGA-04-1332-01         0.932735    0.054339    0.050471      0.876822
# TCGA-04-1335-01         0.943137    0.026842    0.077507      0.712961
#
#                        8             9      ...           22591       22592  \
# ...

# %%
load_and_display_pkl( file_paths["mrnaseqv2"],"mrnaseqv2")
# Out:
# Displaying first 5 rows of mrnaseqv2:
#                      0          1           2            3           4      \
# Hugo_Symbol       UBE2Q2P3   UBE2Q2P2     HMGB1P1       TIMM23   LOC155060
# Entrez_Gene_Id   100133144  100134869       10357        10431      155060
# TCGA-04-1348-01  22.028266  25.716221  321.241331  1952.678661  222.150613
# TCGA-04-1357-01  17.671802  20.473921  128.865135   901.425735   244.41232
# TCGA-04-1362-01   21.97672   29.90998  424.021806  1366.864827  377.449014
#
#                     5         6         7         8         9      ...  \
# Hugo_Symbol      RNU12-2P     EZHIP    EFCAB8   SRP14P1   TRIM75P  ...
# Entrez_Gene_Id      26823    340602    388795    390284    391714  ...
# TCGA-04-1348-01  0.676632 -0.059851  3.038671  4.594825 -0.329284  ...
# TCGA-04-1357-01   0.09028 -0.479632  4.932117   5.20536 -0.329284  ...
# TCGA-04-1362-01  0.451162  4.514755  3.434062  4.371905  0.780617  ...
#
# ...

# %%
load_and_display_pkl( file_paths["log2cna"],"log2cna")
# Out:
# Displaying first 5 rows of log2cna:
#                     0         1         2         3        4        5      \
# Hugo_Symbol         ACAP3    ACTRT2      AGRN   ANKRD65   ATAD3A   ATAD3B
# Entrez_Gene_Id   116983.0  140625.0  375790.0  441869.0  55210.0  83858.0
# TCGA-04-1331-01    -0.704    -0.704    -0.704    -0.704   -0.704   -0.704
# TCGA-04-1332-01      0.08      0.08      0.08      0.08     0.08     0.08
# TCGA-04-1335-01    -0.807    -0.807    -0.807    -0.807   -0.807   -0.807
#
#                     6         7         8         9      ...         25118  \
# Hugo_Symbol        ATAD3C  AURKAIP1   B3GALT6  C1orf159  ...  hsa-mir-1321
# Entrez_Gene_Id   219293.0   54998.0  126792.0   54991.0  ...   100302171.0
# TCGA-04-1331-01    -0.704    -0.704    -0.704    -0.704  ...         0.036
# TCGA-04-1332-01      0.08      0.08      0.08      0.08  ...        -0.237
# TCGA-04-1335-01    -0.807    -0.807    -0.807    -0.807  ...         0.063
#
# ...
